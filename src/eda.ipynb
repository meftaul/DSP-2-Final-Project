# %%
! pip install ydata-profiling dtale
# Out:
# Collecting ydata-profiling
#   Using cached ydata_profiling-4.12.2-py2.py3-none-any.whl.metadata (20 kB)
# Collecting dtale
#   Using cached dtale-3.16.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from ydata-profiling) (1.14.0)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: matplotlib>=3.5 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from ydata-profiling) (3.9.2)
# Requirement already satisfied: pydantic>=2 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from ydata-profiling) (2.8.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from ydata-profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from ydata-profiling) (3.1.4)
# Collecting visions<0.8.0,>=0.7.5 (from visions[type_image_path]<0.8.0,>=0.7.5->ydata-profiling)
#   Using cached visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from ydata-profiling) (1.26.4)
# Collecting htmlmin==0.1.12 (from ydata-profiling)
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling)
#   Downloading phik-0.12.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from ydata-profiling) (4.66.5)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Using cached multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling)
#   Downloading statsmodels-0.14.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting typeguard<5,>=3 (from ydata-profiling)
#   Using cached typeguard-4.4.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling)
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting wordcloud>=1.9.3 (from ydata-profiling)
#   Downloading wordcloud-1.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Using cached dacite-1.9.1-py3-none-any.whl.metadata (17 kB)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling)
#   Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: pillow in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from imagehash==4.3.1->ydata-profiling) (10.4.0)
# Collecting dash-colorscales (from dtale)
#   Using cached dash_colorscales-0.0.4.tar.gz (62 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dash-daq (from dtale)
#   Using cached dash_daq-0.5.0.tar.gz (642 kB)
#   Preparing metadata (setup.py) ... done
# Collecting future>=0.14.0 (from dtale)
#   Using cached future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting missingno (from dtale)
#   Using cached missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Collecting squarify (from dtale)
#   Using cached squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Collecting strsimpy (from dtale)
#   Using cached strsimpy-0.2.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: six in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from dtale) (1.16.0)
# Collecting xlrd (from dtale)
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: beautifulsoup4!=4.13.0b2 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from dtale) (4.12.3)
# Requirement already satisfied: certifi in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from dtale) (2024.7.4)
# Collecting dash-bootstrap-components (from dtale)
#   Using cached dash_bootstrap_components-1.7.1-py3-none-any.whl.metadata (17 kB)
# Collecting lz4 (from dtale)
#   Downloading lz4-4.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: cycler in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from dtale) (0.12.1)
# Requirement already satisfied: dash in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from dtale) (2.17.1)
# Requirement already satisfied: werkzeug in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from dtale) (3.0.3)
# Collecting Flask-Compress (from dtale)
#   Using cached Flask_Compress-1.17-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: scikit-learn in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from dtale) (1.5.1)
# Requirement already satisfied: networkx in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from dtale) (3.3)
# Collecting openpyxl!=3.2.0b1 (from dtale)
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting xarray (from dtale)
#   Downloading xarray-2025.1.2-py3-none-any.whl.metadata (11 kB)
# Collecting scipy<1.16,>=1.4.1 (from ydata-profiling)
#   Downloading scipy-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting et-xmlfile (from dtale)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: plotly in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from dtale) (5.23.0)
# Requirement already satisfied: Flask in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from dtale) (3.0.3)
# Requirement already satisfied: itsdangerous in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from dtale) (2.2.0)
# Collecting kaleido (from dtale)
#   Using cached kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: soupsieve>1.2 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from beautifulsoup4!=4.13.0b2->dtale) (2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from matplotlib>=3.5->ydata-profiling) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from matplotlib>=3.5->ydata-profiling) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from matplotlib>=3.5->ydata-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from matplotlib>=3.5->ydata-profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from matplotlib>=3.5->ydata-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from matplotlib>=3.5->ydata-profiling) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from pydantic>=2->ydata-profiling) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from pydantic>=2->ydata-profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.2.2)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling)
#   Using cached patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: attrs>=19.3.0 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from visions<0.8.0,>=0.7.5->visions[type_image_path]<0.8.0,>=0.7.5->ydata-profiling) (24.2.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from dash->dtale) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from dash->dtale) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from dash->dtale) (5.0.0)
# Requirement already satisfied: importlib-metadata in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from dash->dtale) (8.2.0)
# Requirement already satisfied: retrying in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from dash->dtale) (1.3.4)
# Requirement already satisfied: nest-asyncio in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from dash->dtale) (1.6.0)
# Requirement already satisfied: setuptools in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from dash->dtale) (72.1.0)
# Requirement already satisfied: click>=8.1.3 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from Flask->dtale) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from Flask->dtale) (1.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from plotly->dtale) (9.0.0)
# Collecting brotli (from Flask-Compress->dtale)
#   Downloading Brotli-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting zstandard (from Flask-Compress->dtale)
#   Downloading zstandard-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from scikit-learn->dtale) (3.5.0)
# Requirement already satisfied: zipp>=0.5 in /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages (from importlib-metadata->dash->dtale) (3.20.0)
# Using cached ydata_profiling-4.12.2-py2.py3-none-any.whl (390 kB)
# Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Using cached dtale-3.16.1-py2.py3-none-any.whl (14.7 MB)
# Using cached dacite-1.9.1-py3-none-any.whl (16 kB)
# Using cached future-1.0.0-py3-none-any.whl (491 kB)
# Using cached multimethod-1.12-py3-none-any.whl (10 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading phik-0.12.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (687 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 5.8 MB/s eta 0:00:00
# Downloading scipy-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 MB 9.3 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Downloading statsmodels-0.14.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 8.9 MB/s eta 0:00:00MB/s eta 0:00:01:01
# Using cached typeguard-4.4.1-py3-none-any.whl (35 kB)
# Using cached visions-0.7.6-py3-none-any.whl (104 kB)
# Downloading wordcloud-1.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (547 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.9/547.9 kB 6.0 MB/s eta 0:00:00
# Using cached dash_bootstrap_components-1.7.1-py3-none-any.whl (229 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Using cached Flask_Compress-1.17-py3-none-any.whl (8.7 kB)
# Using cached kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
# Downloading lz4-4.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.4 MB/s eta 0:00:00
# Using cached missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Using cached squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Using cached strsimpy-0.2.1-py3-none-any.whl (45 kB)
# Downloading xarray-2025.1.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.7 MB/s eta 0:00:00
# Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Using cached patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Downloading Brotli-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 9.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 8.9 MB/s eta 0:00:009.4 MB/s eta 0:00:01
# Downloading zstandard-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 7.1 MB/s eta 0:00:007.2 MB/s eta 0:00:01
# Building wheels for collected packages: htmlmin, dash-colorscales, dash-daq
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27083 sha256=564bfa42db606d0f4a9e9e29fbb62a35c7cea143c69f84b897eea88701bc5eb1
#   Stored in directory: /home/meftaul/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
#   Building wheel for dash-colorscales (setup.py) ... done
#   Created wheel for dash-colorscales: filename=dash_colorscales-0.0.4-py3-none-any.whl size=62569 sha256=5e50c9010c9e1474eb9ecd3ad9bb9fd44b74ea690931658ab0a05779cff3e912
#   Stored in directory: /home/meftaul/.cache/pip/wheels/a8/c3/fd/eaaa499af5a62e4f31c6e9ee0a32c05ece15176c4ea4d68398
#   Building wheel for dash-daq (setup.py) ... done
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669693 sha256=28c4302676a809bf862d479f575e3ae93c1da876ba2395d8eac36e1bb716dd1b
#   Stored in directory: /home/meftaul/.cache/pip/wheels/9a/e1/a3/ef7c3fa914e4df214fdcb64529c44669e3e72ebdb784db10e0
# Successfully built htmlmin dash-colorscales dash-daq
# Installing collected packages: strsimpy, squarify, kaleido, htmlmin, dash-colorscales, brotli, zstandard, xlrd, typeguard, scipy, PyWavelets, patsy, multimethod, lz4, future, et-xmlfile, dacite, openpyxl, imagehash, xarray, wordcloud, visions, statsmodels, phik, Flask-Compress, missingno, dash-daq, dash-bootstrap-components, ydata-profiling, dtale
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.0
#     Uninstalling scipy-1.14.0:
#       Successfully uninstalled scipy-1.14.0
# Successfully installed Flask-Compress-1.17 PyWavelets-1.8.0 brotli-1.1.0 dacite-1.9.1 dash-bootstrap-components-1.7.1 dash-colorscales-0.0.4 dash-daq-0.5.0 dtale-3.16.1 et-xmlfile-2.0.0 future-1.0.0 htmlmin-0.1.12 imagehash-4.3.1 kaleido-0.2.1 lz4-4.4.3 missingno-0.5.2 multimethod-1.12 openpyxl-3.1.5 patsy-1.0.1 phik-0.12.4 scipy-1.15.1 squarify-0.4.4 statsmodels-0.14.4 strsimpy-0.2.1 typeguard-4.4.1 visions-0.7.6 wordcloud-1.9.4 xarray-2025.1.2 xlrd-2.0.1 ydata-profiling-4.12.2 zstandard-0.23.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../data/housing.csv')

data.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3996     -117.38     34.44                 4.0       5083.0           867.0
# 14953    -118.33     33.98                38.0       3063.0           796.0
# 5254     -121.53     38.57                34.0       3395.0           592.0
# 16312    -117.87     34.09                36.0       1267.0           191.0
# 10550    -117.12     33.49                 4.0      21988.0          4055.0
#
#        population  households  median_income  median_house_value  \
# 3996       2541.0       856.0         4.2414            121400.0
# 14953      2153.0       721.0         1.8472            149100.0
# 5254       1518.0       627.0         4.0833            118500.0
# 16312       640.0       200.0         5.2405            220000.0
# 10550      8824.0      3252.0         3.9963            191100.0
#
#       ocean_proximity
# 3996           INLAND
# 14953       <1H OCEAN
# 5254           INLAND
# 16312       <1H OCEAN
# 10550       <1H OCEAN

# %%
data.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
num_cols = data.select_dtypes(include=[np.number]).columns
cat_cols = data.select_dtypes('object').columns

print(num_cols)
print(cat_cols)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')
# Index(['ocean_proximity'], dtype='object')

# %%
# from ydata_profiling import ProfileReport

# profile = ProfileReport(data, title="Housing data Report")
# profile.to_file("housing_data_report.html")

# %%
# import dtale

# d = dtale.show(data)
# d.open_browser()

# %%
# d.kill()

# %%
bins = [0, 1.5, 3, 4.5, 6, np.inf]
labels = ['A', 'B', 'C', 'D', 'E']

data['income_cat'] = pd.cut(data['median_income'], bins=bins, labels=labels)

# %%
data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity', 'income_cat'],
#       dtype='object')

# %%
# split the data into train and test
from sklearn.model_selection import train_test_split

train, test = train_test_split(data, 
                               test_size=0.2, 
                               random_state=52,
                               stratify=data['income_cat']
                               )

train.shape, test.shape
# Out:
# ((16512, 11), (4128, 11))

# %%
print(train['income_cat'].value_counts(normalize=True))
print(test['income_cat'].value_counts(normalize=True))
# Out:
# income_cat
# C    0.350594
# B    0.318859
# D    0.176296
# E    0.114462
# A    0.039789
# Name: proportion, dtype: float64
# income_cat
# C    0.350533
# B    0.318798
# D    0.176357
# E    0.114341
# A    0.039971
# Name: proportion, dtype: float64

# %%
print(train.shape, test.shape)

train.columns
# Out:
# (16512, 11) (4128, 11)
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity', 'income_cat'],
#       dtype='object')

# %%
train_set = train.drop(columns=['income_cat']).copy()
test_set = test.drop(columns=['income_cat']).copy()

train_set.shape, test_set.shape
# Out:
# ((16512, 10), (4128, 10))

# %%
train_set.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
X = train_set.drop(columns='median_house_value', axis=1)
y = train_set['median_house_value']

X.shape, y.shape
# Out:
# ((16512, 9), (16512,))

# %%
num_cols
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
X[X.columns]
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity'],
#       dtype='object')

# %%
# import simple imputer
from sklearn.impute import SimpleImputer

num_imputer = SimpleImputer(strategy='mean')
cat_imputer = SimpleImputer(strategy='most_frequent')

num_cols = X.select_dtypes(include=[np.number]).columns
cat_cols = X.select_dtypes('object').columns

# fit the imputer on the training set
X[num_cols] = num_imputer.fit_transform(X[num_cols])
X[cat_cols] = cat_imputer.fit_transform(X[cat_cols])

X.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# ocean_proximity       0
# dtype: int64

# %%
# scale the data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X[num_cols] = scaler.fit_transform(X[num_cols])

# Ordinal encoding
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder()

X[cat_cols] = encoder.fit_transform(X[cat_cols])

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20219   0.616762 -0.684957            1.303949    -0.598891       -0.590719
# 11120   1.341665 -1.393465           -1.556549     0.007883       -0.344897
# 13110  -1.118006  0.746136           -0.364675    -0.101648       -0.402176
# 13436   0.871728 -0.867949           -0.285216    -0.258841       -0.058503
# 9585    0.666755 -0.769414            1.145033    -0.811995       -0.791195
# ...          ...       ...                 ...          ...             ...
# 8998   -1.417966  1.018278           -0.285216    -0.667634        0.017869
# 16976   1.166689 -1.355928            0.350450    -0.300087        0.182545
# 13117  -1.762920  1.647020            0.270992    -0.683675       -0.786421
# 12847   1.266675 -0.760030           -0.364675     0.929502        1.612129
# 14718  -0.993023  1.900394           -1.636007     0.092208       -0.037024
#
#        population  households  median_income  ocean_proximity
# 20219   -0.621990   -0.549766       0.000757              0.0
# 11120   -0.060693   -0.358801       1.250928              0.0
# 13110   -0.164997   -0.309098       1.342745              0.0
# 13436   -0.305542   -0.102437      -0.494422              0.0
# 9585    -0.561883   -0.816594      -1.535830              0.0
# ...           ...         ...            ...              ...
# 8998    -0.735133   -0.152140      -0.105331              3.0
# 16976   -0.324105    0.177471      -0.875854              4.0
# 13117   -0.857116   -0.813978      -0.021122              0.0
# 12847    0.377738    1.613635      -1.275858              1.0
# 14718   -0.230408    0.033594      -0.390119              1.0
#
# [16512 rows x 9 columns]

# %%
X.shape, y.shape
# Out:
# ((16512, 9), (16512,))

# %% [markdown]
# # Model Building

# %%
# linear regression
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression()

# %%
# evaluate the model
from sklearn.metrics import mean_squared_error

# prepare the test data

X_test = test_set.drop(columns='median_house_value', axis=1)
y_test = test_set['median_house_value']

X_test[num_cols] = num_imputer.transform(X_test[num_cols])
X_test[cat_cols] = cat_imputer.transform(X_test[cat_cols])

X_test[num_cols] = scaler.transform(X_test[num_cols])
X_test[cat_cols] = encoder.transform(X_test[cat_cols])

X_test


# make predictions
preds = model.predict(X_test)

# calculate the rmse
rmse = mean_squared_error(y_test, preds)

print(f"RMSE: {rmse}")
# Out:
# RMSE: 4706913176.1258745

# %%
# save the model
import joblib

joblib.dump(model, 'housing_model.pkl')

# save the encoder
joblib.dump(encoder, 'encoder.pkl')

# save the imputer
joblib.dump(num_imputer, 'num_imputer.pkl')

# save the imputer
joblib.dump(cat_imputer, 'cat_imputer.pkl')

# save the scaler
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
# generate a data
new_data = data.sample(1)

# %%
new_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10139    -117.95     33.78                26.0       4115.0           883.0
#
#        population  households  median_income  median_house_value  \
# 10139      2184.0       825.0         3.9536            191000.0
#
#       ocean_proximity income_cat
# 10139       <1H OCEAN          C

# %%
# load the model and other files

model = joblib.load('housing_model.pkl')
encoder = joblib.load('encoder.pkl')
num_imputer = joblib.load('num_imputer.pkl')
scaler = joblib.load('scaler.pkl')
cat_imputer = joblib.load('cat_imputer.pkl')

# prepare the data
new_data[num_cols] = num_imputer.transform(new_data[num_cols])
new_data[cat_cols] = cat_imputer.transform(new_data[cat_cols])

new_data[num_cols] = scaler.transform(new_data[num_cols])
new_data[cat_cols] = encoder.transform(new_data[cat_cols])

# delete the target column and income_cat
new_data = new_data.drop(columns=['median_house_value', 'income_cat'])

# predict
result = model.predict(new_data)

print(f"Predicted value: {result}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 14
#      11 new_data[cat_cols] = cat_imputer.transform(new_data[cat_cols])
#      13 new_data[num_cols] = scaler.transform(new_data[num_cols])
# ---> 14 new_data[cat_cols] = encoder.transform(new_data[cat_cols])
#      16 # delete the target column and income_cat
#      17 new_data = new_data.drop(columns=['median_house_value', 'income_cat'])
#
# File /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages/sklearn/utils/_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:1578, in OrdinalEncoder.transform(self, X)
#    1564 """
#    1565 Transform X to ordinal codes.
#    1566
#    (...)
#    1575     Transformed input.
#    1576 """
#    1577 check_is_fitted(self, "categories_")
# -> 1578 X_int, X_mask = self._transform(
#    1579     X,
#    1580     handle_unknown=self.handle_unknown,
#    1581     force_all_finite="allow-nan",
#    1582     ignore_category_indices=self._missing_indices,
#    1583 )
#    1584 X_trans = X_int.astype(self.dtype, copy=False)
#    1586 for cat_idx, missing_idx in self._missing_indices.items():
#
# File /mnt/misl/miniconda3/envs/misl/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:214, in _BaseEncoder._transform(self, X, handle_unknown, force_all_finite, warn_on_unknown, ignore_category_indices)
#     209 if handle_unknown == "error":
#     210     msg = (
#     211         "Found unknown categories {0} in column {1}"
#     212         " during transform".format(diff, i)
#     213     )
# --> 214     raise ValueError(msg)
#     215 else:
#     216     if warn_on_unknown:
#
# ValueError: Found unknown categories [0.0] in column 0 during transform
